# %% [markdown]
# ## Mass Mobilization Research Notebook

# %% [markdown]
# ### GDelt

# %%
import pandas_gbq

# %%
query = """
    SELECT Year, count(*) as Events FROM `gdelt-bq.full.events` 
GROUP BY Year ORDER BY Year;
"""

event_df = pandas_gbq.read_gbq(query, project_id="gdelt-d-379201")
# Out:
# Downloading: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████|

# %%
event_df = event_df.dropna()
event_df.plot(x="Year", y="Events")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 event_df.plot(x="Year", y="Events")
#
# File ~\anaconda3\envs\cs229\lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\envs\cs229\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\anaconda3\envs\cs229\lib\site-packages\pandas\plotting\_matplotlib\core.py:452, in MPLPlot.generate(self)
# ...

# %% [markdown]
# ### Google Trends

# %%
from pytrends.request import TrendReq

# %%
kw_list = ["blm", "defund", "abolish"]

trends = TrendReq(hl="en-US", tz=360)
trends.build_payload(kw_list, timeframe='today 5-y')
kw_trend_df = trends.interest_over_time()

# %%
kw_trend_df.plot(y=kw_list, use_index=True)
# Out:
# <AxesSubplot: xlabel='date'>

# %% [markdown]
# ### C-SPAN
